# %%
import cv2
cv2.__version__
# Out:
# '4.4.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Import the image
img = cv2.imread('burano.jpg')
plt.imshow(img)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
